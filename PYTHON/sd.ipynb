# %%
def imyour(count):
    if count == 7:
        return imyour()
    print("hey im your boyfriend")
    count = 1
    imyour()
if __name__ == "__main__":
    imyour(0)
# Out:
# hey im your boyfriend
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       6     imyour()
#       7 if __name__ == "__main__":
# ----> 8     imyour(0)
#
# Cell In[13], line 6, in imyour(count)
#       4 print("hey im your boyfriend")
#       5 count = 1
# ----> 6 imyour()
#
# TypeError: imyour() missing 1 required positional argument: 'count'
